# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../data/Dados_Limpos.csv', sep=';')
df.head()
# Out:
#    Temperatura  Umidade  Pressao  Velocidade_Vento  Producao_Agua
# 0         34.5       65     1012               3.2            7.0
# 1         22.0       75     1015               2.0            8.2
# 2         30.5       72     1013               3.8            7.8
# 3         28.0       50     1010               5.0            5.5
# 4         18.0       80     1016               2.5            8.7

# %% [markdown]
# # Ajustes de visualização

# %%
# %matplotlib inline
sns.set(style="whitegrid", palette="muted")

# %% [markdown]
# # Carregando os dados

# %%
df = pd.read_csv("../data/Dados_Limpos.csv", sep=";")

# %% [markdown]
# # Exibindo as 5 primeiras linhas

# %%
print("Visualização Inicial:")
display(df.head())
# Out:
# Visualização Inicial:
#    Temperatura  Umidade  Pressao  Velocidade_Vento  Producao_Agua
# 0         34.5       65     1012               3.2            7.0
# 1         22.0       75     1015               2.0            8.2
# 2         30.5       72     1013               3.8            7.8
# 3         28.0       50     1010               5.0            5.5
# 4         18.0       80     1016               2.5            8.7

# %% [markdown]
# # Informações gerais sobre o dataset

# %%
print("\nInformações do DataFrame:")
df.info()
# Out:
# Informações do DataFrame:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 253 entries, 0 to 252
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Temperatura       253 non-null    float64
#  1   Umidade           253 non-null    int64
#  2   Pressao           253 non-null    int64
#  3   Velocidade_Vento  253 non-null    float64
#  4   Producao_Agua     253 non-null    float64
# dtypes: float64(3), int64(2)
# memory usage: 10.0 KB

# %% [markdown]
# # Verificando valores ausentes

# %%
print("\nValores ausentes por coluna:")
print(df.isnull().sum())
# Out:
# Valores ausentes por coluna:
# Temperatura         0
# Umidade             0
# Pressao             0
# Velocidade_Vento    0
# Producao_Agua       0
# dtype: int64

# %% [markdown]
# # Estatísticas descritivas

# %%
print("\nEstatísticas descritivas (numéricas):")
display(df.describe())
# Out:
# Estatísticas descritivas (numéricas):
#        Temperatura     Umidade      Pressao  Velocidade_Vento  Producao_Agua
# count   253.000000  253.000000   253.000000        253.000000     253.000000
# mean     28.456522   64.616601  1011.592885          3.703162       7.002372
# std       3.839292    7.412937     1.541834          0.704964       0.805828
# min      17.000000   30.000000  1008.000000          1.900000       3.500000
# 25%      28.000000   60.000000  1010.000000          3.500000       6.500000
# 50%      29.500000   64.000000  1011.000000          3.800000       6.900000
# 75%      31.000000   67.000000  1012.000000          4.100000       7.200000
# max      38.000000   85.000000  1017.000000          6.000000       9.200000

# %% [markdown]
# # Estatísticas descritivas (categóricas)

# %%
print("\nColunas categóricas:")
cat_cols = df.select_dtypes(include='object').columns
for col in cat_cols:
    print(f"\nFrequência de valores em '{col}':")
    print(df[col].value_counts())
# Out:
# Colunas categóricas:

# %% [markdown]
# # Correlação entre variáveis numéricas

# %%
print("\nMatriz de correlação:")
plt.figure(figsize=(10,8))
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Matriz de Correlação")
plt.show()
# Out:
# Matriz de correlação:

# %% [markdown]
# # Histograma para variáveis numéricas

# %%
print("\nDistribuição das variáveis numéricas:")
df.select_dtypes(include='number').hist(figsize=(15,10), bins=20)
plt.suptitle("Distribuições das variáveis numéricas")
plt.tight_layout()
plt.show()
# Out:
# Distribuição das variáveis numéricas:

# %% [markdown]
# # Boxplots para detectar outliers

# %%
print("\nBoxplots para detectar outliers:")
for col in df.select_dtypes(include='number').columns:
    plt.figure(figsize=(6, 2))
    sns.boxplot(data=df, x=col)
    plt.title(f'Boxplot de {col}')
    plt.tight_layout()
    plt.show()
# Out:
# Boxplots para detectar outliers:

# %% [markdown]
# # Gráficos de barras para colunas categóricas

# %%
print("\nGráficos de barras para variáveis categóricas:")
for col in cat_cols:
    plt.figure(figsize=(6,3))
    sns.countplot(data=df, x=col)
    plt.title(f'Distribuição de {col}')
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.show()
# Out:
# Gráficos de barras para variáveis categóricas:
